# %% [markdown]
# # 项目：评估和清理英国电商公司销售数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，根据市场销售数据，挖掘畅销产品，以便制定更有效的市场策略来提升营收。
#
# 本实战项目的目的在于练习评估数据干净和整洁度，并且基于评估结果，对数据进行清洗，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了一家英国在线零售公司在2010年12月1日至2011年12月9日期间的所有交易情况，涵盖了该公司在全球不同国家和地区的业务数据。该公司主要销售覆盖各个场景的礼品，包括但不限于生日礼品、结婚纪念品、圣诞礼品等等。该公司的客户群体主要包括批发商和个人消费者，其中批发商占据了相当大的比例。

# %% [markdown]
# 数据每列的含义如下：
# - `InvoiceNo`: 发票号码。6位数，作为交易的唯一标识符。如果这个代码以字母“c”开头，表示这笔交易被取消。
# - `StockCode`: 产品代码。5位数，作为产品的唯一标识符。
# - `Description`: 产品名称。
# - `Quantity`: 产品在交易中的数量。
# - `InvoiceDate`: 发票日期和时间。交易发生的日期和时间。
# - `UnitPrice`: 单价。价格单位为英镑（£）。
# - `CustomerID`: 客户编号。5位数，作为客户的唯一标识符。
# - `Country`: 国家名称。客户所居住的国家的名称。

# %% [markdown]
# ## 读取数据

# %%
import pandas as pd
e_commerce = pd.read_csv("../data/e_commerce.csv")
pd.set_option("display.max_colwidth",100)
e_commerce.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom

# %% [markdown]
# ## 评估数据

# %%
e_commerce.sample(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 531024    580901     22487   WHITE WOOD GARDEN PLANT LADDER         1
# 59607     541357     84946  ANTIQUE SILVER TEA GLASS ETCHED        18
# 389088    570465     21929   JUMBO BAG PINK VINTAGE PAISLEY         1
# 143473    548703     22383           LUNCH BAG SUKI DESIGN          2
# 463431    576062     22867          HAND WARMER BIRD DESIGN         5
# 176897    552037     22966    GINGERBREAD MAN COOKIE CUTTER        24
# 455137    575607     22961           JAM MAKING SET PRINTED         7
# 198898    554075     21788               KIDS RAIN MAC BLUE        24
# 65315     541695     22945   CHRISTMAS METAL TAGS ASSORTED          1
# 284305    561869     22191           IVORY DINER WALL CLOCK         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 531024   12/6/2011 12:45       9.95     16528.0  United Kingdom
# 59607    1/17/2011 14:40       1.25     14238.0  United Kingdom
# ...

# %%
e_commerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
e_commerce[e_commerce["Description"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %%
e_commerce[(e_commerce["Description"].isnull())&(e_commerce["UnitPrice"]!=0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
e_commerce[e_commerce["CustomerID"].isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/2010 11:52       0.00         NaN  United Kingdom
# ...

# %%
e_commerce[e_commerce.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
e_commerce["Country"].value_counts()
# Out:
# Country
# United Kingdom          495266
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# China                      288
# Singapore                  229
# USA                        218
# UK                         211
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# ...

# %%
e_commerce.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
e_commerce[e_commerce["Quantity"]<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
e_commerce[(e_commerce["Quantity"]<0)&(e_commerce["InvoiceNo"].str[0]!="C")]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 2406      536589     21777         NaN       -10  12/1/2010 16:50        0.0
# 4347      536764    84952C         NaN       -38  12/2/2010 14:42        0.0
# 7188      536996     22712         NaN       -20  12/3/2010 15:30        0.0
# 7189      536997     22028         NaN       -20  12/3/2010 15:30        0.0
# 7190      536998     85067         NaN        -6  12/3/2010 15:30        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535333    581210     23395       check       -26  12/7/2011 18:36        0.0
# 535335    581212     22578        lost     -1050  12/7/2011 18:38        0.0
# 535336    581213     22576       check       -30  12/7/2011 18:38        0.0
# 536908    581226     23090     missing      -338   12/8/2011 9:56        0.0
# 538919    581422     23169     smashed      -235  12/8/2011 15:24        0.0
#
#         CustomerID         Country
# ...

# %%
e_commerce[(e_commerce["Quantity"]<0)&(e_commerce["InvoiceNo"].str[0]!="C")&(e_commerce["UnitPrice"]!=0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
e_commerce[e_commerce["UnitPrice"]<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ## 清理数据

# %%
cleaned_e_commerce = e_commerce.copy()

# %%
cleaned_e_commerce["InvoiceDate"] = pd.to_datetime(cleaned_e_commerce["InvoiceDate"])
cleaned_e_commerce["InvoiceDate"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
cleaned_e_commerce["CustomerID"] = cleaned_e_commerce["CustomerID"].astype(str)
cleaned_e_commerce["CustomerID"]
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 541909, dtype: object

# %%
cleaned_e_commerce["CustomerID"] = cleaned_e_commerce["CustomerID"].str.slice(0,-2)
cleaned_e_commerce["CustomerID"]
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: CustomerID, Length: 541909, dtype: object

# %%
cleaned_e_commerce.dropna(subset = ["Description"], inplace =True)
cleaned_e_commerce[cleaned_e_commerce["Description"].isnull()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
cleaned_e_commerce["Country"] = cleaned_e_commerce["Country"].replace({"USA":"United Stated"})

# %%
len(cleaned_e_commerce[cleaned_e_commerce["Country"] == "USA"])
# Out:
# 0

# %%
cleaned_e_commerce["Country"] = cleaned_e_commerce["Country"].replace({"UK":"United Kingdom", "U.K.": "United Kingdom"})

# %%
len(cleaned_e_commerce[(cleaned_e_commerce["Country"] == "UK")|(cleaned_e_commerce["Country"] == "U.K.")])
# Out:
# 0

# %%
cleaned_e_commerce = cleaned_e_commerce[cleaned_e_commerce["Quantity"]>=0]

# %%
len(cleaned_e_commerce[cleaned_e_commerce["Quantity"]<0])
# Out:
# 0

# %%
cleaned_e_commerce = cleaned_e_commerce[cleaned_e_commerce["UnitPrice"]>=0]

# %%
len(cleaned_e_commerce[cleaned_e_commerce["UnitPrice"]<0])
# Out:
# 0

# %% [markdown]
# ## 保存清理后的数据

# %%
cleaned_e_commerce.to_csv("e_commerce_cleaned.csv", index = False)

# %%
pd.read_csv("e_commerce_cleaned.csv").head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4152\2686214642.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("e_commerce_cleaned.csv").head()
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice CustomerID         Country
# 0  2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1  2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2  2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3  2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...
